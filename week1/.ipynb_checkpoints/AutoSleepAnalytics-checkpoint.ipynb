# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import decimal

df = pd.read_csv('./AutoSleepData.csv')
#df.drop(["fromDate", "toDate"], axis="columns", inplace=True)

df = df.dropna()

df["Time"] = pd.to_datetime(df['Time'])
df["bedtime"] = pd.to_datetime(df['bedtime'])
df["waketime"] = pd.to_datetime(df['waketime'])
df["asleep"] = pd.to_datetime(df['asleep'])
df["quality"] = pd.to_datetime(df['quality'])
df["deep"] = pd.to_datetime(df['deep'])

df["bedtime_hour"] = df["bedtime"].dt.hour
df.loc[df['bedtime'].dt.minute >= 30, 'bedtime_hour'] = df['bedtime_hour'] + 0.5

df["asleep_minutes"] = df['asleep'].dt.hour * 60 + round(df['asleep'].dt.minute, -1)
df["quality_minutes"] = df['quality'].dt.hour * 60 + round(df['quality'].dt.minute, -1)
df["deep_minutes"] = df['deep'].dt.hour * 60 + round(df['deep'].dt.minute, -1)
df["quality_ratio"] = df["quality_minutes"] / df["asleep_minutes"]
df["deep_ratio"] = df["deep_minutes"] / df["asleep_minutes"]

df = df.loc[df['asleep_minutes']  < 720]
df = df.loc[df['quality_ratio']  < 1]
df = df.loc[df['quality_ratio']  < 1]
df = df.loc[(df['bedtime_hour']  > 18) | (df['bedtime_hour']  < 10)]

df.head()
# Out:
#                        Time             bedtime            waketime     inBed  \
# 0 2021-01-05 21:59:59+09:00 2021-01-05 04:31:00 2021-01-05 09:57:00  05:26:00
# 1 2021-01-06 21:59:59+09:00 2021-01-06 02:58:00 2021-01-06 13:02:00  10:04:00
# 2 2021-01-07 21:59:59+09:00 2021-01-07 02:00:00 2021-01-07 09:44:00  07:44:00
# 3 2021-01-08 21:59:59+09:00 2021-01-08 01:40:00 2021-01-08 09:26:00  07:46:00
# 4 2021-01-09 21:59:59+09:00 2021-01-09 03:30:00 2021-01-09 07:31:00  04:01:00
#
#       awake              asleep asleepAvg7  efficiency  efficiencyAvg7  \
# 0  00:00:00 2022-06-23 05:26:00   05:26:00       100.0           100.0
# 1  02:31:00 2022-06-23 07:33:00   06:29:30        75.0            87.5
# 2  00:00:00 2022-06-23 07:44:00   06:54:20       100.0            91.7
# 3  00:00:00 2022-06-23 07:46:00   07:07:15       100.0            93.8
# 4  00:00:00 2022-06-23 04:01:00   06:30:00       100.0            95.0
#
#               quality  ... wakingBPM wakingBPMAvg7   hrv  hrvAvg7  \
# 0 2022-06-23 04:27:12  ...      60.0          60.0  46.0     46.0
# 1 2022-06-23 06:01:45  ...      74.0          67.0  38.0     42.0
# 2 2022-06-23 06:42:36  ...      65.0          66.3  48.0     44.0
# 3 2022-06-23 07:14:44  ...      70.0          67.2  34.0     42.0
# 4 2022-06-23 03:54:43  ...      68.0          67.4  22.0     38.0
#
#    bedtime_hour  asleep_minutes  quality_minutes  deep_minutes  quality_ratio  \
# 0           4.5             330              270           130       0.818182
# 1           2.5             450              360           200       0.800000
# 2           2.0             460              400           220       0.869565
# 3           1.5             470              430           300       0.914894
# 4           3.5             240              230           160       0.958333
#
#    deep_ratio
# 0    0.393939
# 1    0.444444
# 2    0.478261
# 3    0.638298
# 4    0.666667
#
# [5 rows x 27 columns]

# %%
sleep_data = df[["quality_ratio","deep_ratio",  "bedtime_hour", "asleep_minutes"]]
sleep_data = sleep_data.groupby(['bedtime_hour'], as_index=False).mean()
sleep_data.loc[sleep_data['bedtime_hour'] > 18, 'bedtime_hour'] = df['bedtime_hour'] - 6
print(sleep_data)
# Out:
#     bedtime_hour  quality_ratio  deep_ratio  asleep_minutes
# 0            0.0       0.861328    0.466168      481.142857
# 1            0.5       0.860207    0.461366      455.581395
# 2            1.0       0.850601    0.433415      455.161290
# 3            1.5       0.852848    0.444294      426.785714
# 4            2.0       0.852485    0.454743      419.473684
# 5            2.5       0.843795    0.424310      396.279070
# 6            3.0       0.855537    0.434411      403.823529
# 7            3.5       0.869405    0.460053      356.111111
# 8            4.0       0.872862    0.460132      348.750000
# 9            4.5       0.860626    0.453377      351.666667
# 10           5.0       0.832170    0.369977      374.000000
# 11           5.5       0.840857    0.430235      290.000000
# 12           6.0       0.857627    0.488480      286.666667
# 13           7.0       0.890780    0.538652      385.000000
# 14           8.5       0.871795    0.307692      390.000000
# 15           9.5       0.909091    0.636364      220.000000
# 16          -3.0       0.856759    0.481412      640.000000
# 17          -4.5       0.934469    0.572755      540.000000
# 18          -4.0       0.828834    0.497239      431.000000
# 19          -4.0       0.835395    0.449978      497.500000

# %%
plt.bar(sleep_data["bedtime_hour"], sleep_data["quality_ratio"])
plt.ylim(0.8, 0.95)
plt.show()

# %%
plt.bar(sleep_data["bedtime_hour"], sleep_data["deep_ratio"])
plt.ylim(0.25, 0.6)
plt.show()
